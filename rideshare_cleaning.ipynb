# %%
import pandas as pd

# %%
# Define file pathname
base = "/Users/ziadharmanani/Documents/GitHub/INF1340-Group7/INF1340-Data/Bike share ridership "
extension = [
    "2022-01", "2022-02", "2022-03", "2022-04", "2022-05", "2022-06",
    "2022-07", "2022-08", "2022-09", "2022-10", "2022-11", "2022-12",
    "2023-01", "2023-02", "2023-03", "2023-04", "2023-05", "2023-06",
    "2023-07", "2023-08", "2023-09", "2023-10", "2023-11", "2023-12",
    "2024-01", "2024-02", "2024-03", "2024-04", "2024-05", "2024-06",
    "2024-07", "2024-08", "2024-09"
    ]

# Define columns order in a list
columns = [
    "Trip Id", "Trip  Duration", "Start Station Id", "Start Time",
    "Start Station Name", "End Station Id", "End Time",
    "End Station Name", "Bike Id", "User Type"
    ]

# Used to store file paths
paths = []

# Loop through file extensions and combine them to locate them individually
for month in extension:
    path = base + month + ".csv"
    paths.append(path)

# Used to store the individual data frames
all_dfs = []

# Clean columns (Inconsistencies between 2024 and other years)
# Mismatch beteen the years issued a lot of NaN values. Trip Id was duplicated (2024 had its own).
for file in paths:
    df_temp = pd.read_csv(file, encoding = "latin1")
    df_temp.columns = [col.replace("ï»¿", "").strip() for col in df_temp.columns]

    # Used to clean BOM character for "Trip Id" (2024)
    if "ï»¿Trip Id" in df_temp.columns:
        df_temp["Trip Id"] = df_temp["ï»¿Trip Id"]
        df_temp = df_temp.drop(columns = ["ï»¿Trip Id"])
    
    # Reindexes the data frame according to columns list.
    df_temp = df_temp.reindex(columns = columns)
    all_dfs.append(df_temp)

# Concatinate dataframe
df = pd.concat(all_dfs, ignore_index = True)

# Drop "Model" to stay consistent with previous years (Only present in 2024)
df = df.drop(columns = ["Model", "Bike Id"], errors = "ignore")

# NEXT STEPS: Look into Start Station Name and End Station Name.

# %%
df.sample(10)
# Out:
#            Trip Id  Trip  Duration  Start Station Id        Start Time  \
# 13018428  29765231            1244              7927    7/2/2024 19:06
# 9945712   26247667            1039              7389  11/19/2023 13:17
# 11343823  27839371             471              7524  04/19/2024 13:57
# 7521166   23477655              74              7467  07/30/2023 10:56
# 2090179   17264872            1723              7440  07/22/2022 14:26
# 10630537  27020798             319              7161  02/09/2024 20:26
# 1422287   16491147             567              7508  06/21/2022 13:41
# 14021053  30927228             413              7297  08/06/2024 17:50
# 12935873  29669858             443              7577  06/29/2024 17:10
# 7938232   23956790             446              7000  08/16/2023 09:23
#
#                               Start Station Name  End Station Id  \
# 13018428  Strachan Ave / East Liberty St - SMART          7289.0
# 9945712           College Park- Gerrard Entrance          7287.0
# 11343823                             Lisgar Park          7720.0
# 7521166           Lower Simcoe St / Bremner Blvd          7467.0
# 2090179        Martin Goodman Trail / Ontario Dr          7256.0
# 10630537                Beverley St / College St          7002.0
# 1422287        Berkeley St / Dundas St E - SMART          7462.0
# 14021053             Havelock St / Dufferin Park          7791.0
# 12935873                      Oak St / Sumach St          7106.0
# 7938232             Fort York  Blvd / Capreol Ct          7469.0
#
#                   End Time                  End Station Name      User Type
# 13018428    7/2/2024 19:27       Humber Bay Shores Park East  Casual Member
# 9945712   11/19/2023 13:34     Queen St E / Pape Ave - SMART  Casual Member
# 11343823  04/19/2024 14:05           King St W / Portland St  Casual Member
# 7521166   07/30/2023 10:57    Lower Simcoe St / Bremner Blvd  Casual Member
# 2090179   07/22/2022 14:55  Vanauley St / Queen St W - SMART  Casual Member
# 10630537  02/09/2024 20:31        St. George St / Bloor St W  Annual Member
# 1422287   06/21/2022 13:51          Richmond St E / Yonge St  Casual Member
# 14021053  08/06/2024 17:56          Ossington Ave / Bruce St  Casual Member
# 12935873  06/29/2024 17:18              Mill St / Tannery Rd  Casual Member
# 7938232   08/16/2023 09:30         Wellington St W / York St  Casual Member

# %%
df.isna().sum()
# Out:
# Trip Id                    0
# Trip  Duration             0
# Start Station Id           0
# Start Time                 0
# Start Station Name    891502
# End Station Id          4318
# End Time                   0
# End Station Name      898371
# Bike Id                    0
# User Type                  0
# dtype: int64
